# %% [markdown]
# <a href="https://colab.research.google.com/github/AxelEdogawa/Machine_Learning/blob/dev_cost/__init___py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Cost functions module.

This package provides a common interface for different cost functions
used in machine learning models.
"""

from .cost import CostFunction, MeanSquaredError

__all__ = [
    "CostFunction",
    "MeanSquaredError",
]
